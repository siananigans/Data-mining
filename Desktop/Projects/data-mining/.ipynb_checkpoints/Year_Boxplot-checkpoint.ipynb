# %%
import pandas
import matplotlib

data = pandas.read_csv('meteorite-landings.csv')

# %%
years = data['year']
years.to_list()
# Out:
# [1880.0,
#  1951.0,
#  1952.0,
#  1976.0,
#  1902.0,
#  1919.0,
#  1949.0,
#  1814.0,
#  1930.0,
#  1920.0,
#  1974.0,
#  1925.0,
#  1769.0,
#  1949.0,
#  1838.0,
#  1959.0,
#  1981.0,
#  1957.0,
#  2001.0,
#  1806.0,
#  1766.0,
#  1949.0,
#  2002.0,
#  1835.0,
#  1873.0,
#  1860.0,
#  1900.0,
#  1883.0,
#  1899.0,
#  1969.0,
#  2008.0,
#  1977.0,
#  1895.0,
#  1880.0,
#  1898.0,
#  1969.0,
#  1939.0,
#  nan,
#  1822.0,
#  1869.0,
#  1942.0,
#  1971.0,
#  1984.0,
#  1914.0,
#  1803.0,
#  1954.0,
#  1932.0,
#  1950.0,
#  1805.0,
#  2009.0,
#  1923.0,
#  1886.0,
#  1920.0,
#  1896.0,
#  1933.0,
#  1945.0,
#  1836.0,
#  1865.0,
#  1842.0,
#  1858.0,
#  1952.0,
#  1908.0,
#  1855.0,
#  1968.0,
#  1938.0,
#  1814.0,
#  1934.0,
#  1929.0,
#  1922.0,
#  1907.0,
#  1993.0,
#  1871.0,
#  1892.0,
#  1913.0,
#  1933.0,
#  1790.0,
#  1704.0,
#  1842.0,
#  1904.0,
#  1886.0,
#  1910.0,
#  1965.0,
#  2006.0,
#  1994.0,
#  1892.0,
#  1902.0,
#  2012.0,
#  1989.0,
#  1916.0,
#  1929.0,
#  1893.0,
# ...

# %%
years[len(years)-1] - years[0]
# Out:
# 96.0

# %%
len(years)/4

# %%
i = 0
while i < len(years):
    if i == 11429:
        a = year[i]
        
    elif i == 22858:
        b = year[i]
    
    elif i == 33287:
        c = year[i]
        
    i+=1

print(a)
